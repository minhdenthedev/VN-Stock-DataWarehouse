# %%
import pandas as pd
import os
from datetime import datetime

class DataTransformer:
    def __init__(self, stock_codes, table_names, input_folder="parsed_data_raw", output_folder="processed_data"):
        self.stock_codes = stock_codes
        self.table_names = table_names
        self.input_folder = input_folder
        self.output_folder = output_folder

    def process_financial_report(self, stock_code, table_name):
        input_folder_path = os.path.join("..", "..", "parsed_data_raw", "csv", table_name, f"{stock_code}_csv")
        output_folder_path = os.path.join(self.output_folder, "csv", table_name, f"{stock_code}_processed")
        os.makedirs(output_folder_path, exist_ok=True)

        all_results = []  # Danh sách lưu tất cả kết quả

        for file_name in os.listdir(input_folder_path):
            if file_name.endswith(".csv"):
                input_csv = os.path.join(input_folder_path, file_name)
                print(f"🔄 Đang xử lý: {input_csv}")

                df = pd.read_csv(input_csv, header=0).dropna(how='all')
                quarters = df.columns[1:]

                records = []
                for _, row in df.iterrows():
                    indicator = str(row.iloc[0]).strip()
                    if indicator in ["Giai đoạn", "Hợp nhất", "Kiểm toán", "Công ty kiểm toán", "Ý kiến kiểm toán"]:
                        continue

                    for quarter in quarters:
                        quarter_formatted = quarter.replace("/", "")
                        report_id = f"{stock_code}BCKQKD{quarter_formatted}"
                        value = str(row[quarter]).replace(",", "")

                        if value in ["", "nan", "None"]:
                            continue

                        ingestion_date = updated_date = datetime.now().strftime("%Y-%m-%d")
                        records.append([report_id, indicator, value, ingestion_date, updated_date])

                df_result = pd.DataFrame(records, columns=["report_id", "index", "value", "ingestion_date", "updated_date"])
                all_results.append(df_result)  # Thêm kết quả vào danh sách

                # Đặt tên file đầu ra dựa trên file gốc
                output_csv = os.path.join(output_folder_path, f"processed_{file_name}")
                df_result.to_csv(output_csv, index=False, encoding="utf-8")
                
                print(f"✅ File đã được lưu tại: {output_csv}")

        return all_results  # Trả về danh sách kết quả thay vì một file duy nhất

    def run(self, table_name):
        for stock_code in self.stock_codes:
            print(f"🔄 Đang xử lý: {stock_code} - {table_name}")
            self.process_financial_report(stock_code, table_name)

if __name__ == "__main__":
    stock_codes = [
        "ACB", "BCM", "BID", "BVH", "CTG", "FPT", "GAS", "GVR", "HDB", "HPG",
        "LPB", "MBB", "MSN", "MWG", "PLX", "SAB", "SHB", "SSB", "SSI", "STB",
        "TCB", "TPB", "VCB", "VHM", "VIC", "VJC", "VNM", "VPB", "VRE"
    ]

    table_names = {"inc_state", "balance", "cash_flow"}

    transformer = DataTransformer(stock_codes, table_names)
    transformer.run(table_name="balance")
# Out:
# 🔄 Đang xử lý: ACB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_14.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_15.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\ACB_processed\processed_ACB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: BCM - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BCM_processed\processed_BCM_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BCM_processed\processed_BCM_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BCM_processed\processed_BCM_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BCM_processed\processed_BCM_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BCM_processed\processed_BCM_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BCM_processed\processed_BCM_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BCM_processed\processed_BCM_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: BID - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BID_processed\processed_BID_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: BVH - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\BVH_processed\processed_BVH_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: CTG - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\CTG_processed\processed_CTG_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: FPT - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_14.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_15.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\FPT_processed\processed_FPT_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: GAS - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GAS_processed\processed_GAS_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: GVR - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GVR_processed\processed_GVR_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GVR_processed\processed_GVR_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GVR_processed\processed_GVR_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GVR_processed\processed_GVR_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GVR_processed\processed_GVR_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GVR_processed\processed_GVR_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\GVR_processed\processed_GVR_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: HDB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HDB_processed\processed_HDB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: HPG - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_14.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_15.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\HPG_processed\processed_HPG_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: LPB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\LPB_processed\processed_LPB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\LPB_processed\processed_LPB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\LPB_processed\processed_LPB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\LPB_processed\processed_LPB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\LPB_processed\processed_LPB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\LPB_processed\processed_LPB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\LPB_processed\processed_LPB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\LPB_processed\processed_LPB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\LPB_processed\processed_LPB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: MBB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MBB_processed\processed_MBB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: MSN - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MSN_processed\processed_MSN_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: MWG - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MWG_processed\processed_MWG_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MWG_processed\processed_MWG_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MWG_processed\processed_MWG_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MWG_processed\processed_MWG_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MWG_processed\processed_MWG_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MWG_processed\processed_MWG_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MWG_processed\processed_MWG_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MWG_processed\processed_MWG_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\MWG_processed\processed_MWG_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: PLX - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\PLX_processed\processed_PLX_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: SAB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SAB_processed\processed_SAB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SAB_processed\processed_SAB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SAB_processed\processed_SAB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SAB_processed\processed_SAB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SAB_processed\processed_SAB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SAB_processed\processed_SAB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SAB_processed\processed_SAB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SAB_processed\processed_SAB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SAB_processed\processed_SAB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: SHB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SHB_processed\processed_SHB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: SSB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSB_processed\processed_SSB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSB_processed\processed_SSB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSB_processed\processed_SSB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSB_processed\processed_SSB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSB_processed\processed_SSB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSB_processed\processed_SSB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSB_processed\processed_SSB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: SSI - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_14.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_15.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\SSI_processed\processed_SSI_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: STB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_14.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_15.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\STB_processed\processed_STB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: TCB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TCB_processed\processed_TCB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: TPB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TPB_processed\processed_TPB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TPB_processed\processed_TPB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TPB_processed\processed_TPB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TPB_processed\processed_TPB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TPB_processed\processed_TPB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TPB_processed\processed_TPB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TPB_processed\processed_TPB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TPB_processed\processed_TPB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\TPB_processed\processed_TPB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: VCB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VCB_processed\processed_VCB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: VHM - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VHM_processed\processed_VHM_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VHM_processed\processed_VHM_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VHM_processed\processed_VHM_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VHM_processed\processed_VHM_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VHM_processed\processed_VHM_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VHM_processed\processed_VHM_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VHM_processed\processed_VHM_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VHM_processed\processed_VHM_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: VIC - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_14.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_15.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VIC_processed\processed_VIC_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: VJC - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VJC_processed\processed_VJC_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VJC_processed\processed_VJC_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VJC_processed\processed_VJC_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VJC_processed\processed_VJC_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VJC_processed\processed_VJC_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VJC_processed\processed_VJC_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VJC_processed\processed_VJC_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VJC_processed\processed_VJC_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: VNM - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_11.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_12.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_13.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_14.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_15.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_16.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_16.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VNM_processed\processed_VNM_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: VPB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_10.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_8.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_9.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VPB_processed\processed_VPB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: VRE - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_1.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VRE_processed\processed_VRE_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_2.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VRE_processed\processed_VRE_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_3.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VRE_processed\processed_VRE_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_4.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VRE_processed\processed_VRE_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_5.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VRE_processed\processed_VRE_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_6.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VRE_processed\processed_VRE_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_7.csv
# ✅ File đã được lưu tại: processed_data\csv\balance\VRE_processed\processed_VRE_tbl-data-CDKT_7.csv

# %%
import os

input_folder = "parsed_data_raw"
table_name = "balance"
stock_code = "ACB"

input_folder_path = os.path.join("..", "..", "parsed_data_raw", "csv", table_name, f"{stock_code}_csv")

if os.path.exists(input_folder_path):
    print(f"✅ Thư mục tồn tại: {input_folder_path}")
else:
    print(f"❌ Thư mục KHÔNG tồn tại: {input_folder_path}")
# Out:
# ✅ Thư mục tồn tại: ..\..\parsed_data_raw\csv\balance\ACB_csv

# %%
input_folder_path = os.path.abspath(os.path.join("..", "..", "parsed_data_raw", "csv", table_name, f"{stock_code}_csv"))
print(f"📂 Đường dẫn thực tế: {input_folder_path}")
# Out:
# 📂 Đường dẫn thực tế: d:\Project\stock-crawler\parsed_data_raw\csv\balance\ACB_csv

# %% [markdown]
# Test 2

# %%
import csv
import os
import openpyxl
from collections import defaultdict

class DataTransformer:
    def __init__(self, stock_codes, input_folder="parsed_data_raw", output_folder="processed_data"):
        self.stock_codes = stock_codes
        self.input_folder = input_folder
        self.output_folder = output_folder

    def process_financial_report(self, stock_code, table_name):
        """Xử lý báo cáo tài chính và giữ nguyên thứ tự index"""

        # 📁 Đường dẫn input và output
        input_folder_path = os.path.join("..", "..", "parsed_data_raw", "csv", table_name, f"{stock_code}_csv")
        output_folder_path = os.path.join(self.output_folder, "csv", table_name)
        os.makedirs(output_folder_path, exist_ok=True)

        data_dict = defaultdict(dict)  # Lưu dữ liệu dạng { (stock_code, time): {index: value} }
        index_order = []  # Giữ nguyên thứ tự xuất hiện của index

        # 📂 Đọc từng file CSV
        for file_name in os.listdir(input_folder_path):
            if file_name.endswith(".csv"):
                input_csv = os.path.join(input_folder_path, file_name)
                print(f"🔄 Đang xử lý: {input_csv}")

                with open(input_csv, "r", encoding="utf-8") as f:
                    reader = csv.reader(f)
                    headers = next(reader)  # Lấy tiêu đề

                    quarters = headers[1:]  # Các cột quý (VD: "2023/Q1", "2023/Q2")

                    for row in reader:
                        indicator = row[0].strip()

                        if indicator in ["Giai đoạn", "Hợp nhất", "Kiểm toán", "Công ty kiểm toán", "Ý kiến kiểm toán"]:
                            continue  # Bỏ qua các chỉ số không cần thiết

                        # 🔄 Duy trì thứ tự index
                        if indicator not in index_order:
                            index_order.append(indicator)

                        for i, quarter in enumerate(quarters):
                            quarter_formatted = quarter.replace("/", "")  # Chuẩn hóa định dạng thời gian
                            value = row[i + 1].replace(",", "").strip()

                            # ⚠️ Giữ nguyên giá trị rỗng
                            if value in ["", "nan", "None"]:
                                value = ""

                            # Chuyển đổi số nếu có thể
                            try:
                                value = float(value) if value else ""
                            except ValueError:
                                pass  # Nếu không phải số, giữ nguyên

                            data_dict[(stock_code, quarter_formatted)][indicator] = value

        # 📁 Ghi dữ liệu ra file CSV
        output_csv = os.path.join(output_folder_path, f"{stock_code}_transformed.csv")
        data_list = []

        with open(output_csv, "w", encoding="utf-8", newline="") as f:
            writer = csv.writer(f)

            # 📝 Ghi header: ["stock_code", "time", chỉ số tài chính...]
            writer.writerow(["stock_code", "time"] + index_order)

            # 📝 Ghi dữ liệu theo thứ tự
            for (stock_code, time), values in sorted(data_dict.items()):
                row = [stock_code, time] + [values.get(index, "") for index in index_order]
                writer.writerow(row)
                data_list.append(row)

        print(f"✅ File CSV đã được lưu tại: {output_csv}")

        # 📁 Ghi dữ liệu ra file Excel
        output_excel_folder = os.path.join(self.output_folder, "excel", table_name)
        os.makedirs(output_excel_folder, exist_ok=True)  # Đảm bảo thư mục tồn tại
        output_excel = os.path.join(output_excel_folder, f"{stock_code}_processed.xlsx")
        
        self.save_to_excel(output_excel, ["stock_code", "time"] + index_order, data_list)

    def save_to_excel(self, file_path, headers, data):
        """Lưu dữ liệu vào file Excel"""
        workbook = openpyxl.Workbook()
        sheet = workbook.active
        sheet.append(headers)  # Ghi tiêu đề

        for row in data:
            sheet.append(row)  # Ghi dữ liệu

        workbook.save(file_path)
        print(f"✅ File Excel đã được lưu tại: {file_path}")

    def run(self, table_name):
        for stock_code in self.stock_codes:
            print(f"\n🔄 Đang xử lý: {stock_code} - {table_name}")
            self.process_financial_report(stock_code, table_name)

if __name__ == "__main__":
    stock_codes = [
        "ACB", "BCM", "BID", "BVH", "CTG", "FPT", "GAS", "GVR", "HDB", "HPG",
        "LPB", "MBB", "MSN", "MWG", "PLX", "SAB", "SHB", "SSB",
        "SSI", "STB",
        "TCB", "TPB", "VCB", "VHM", "VIC", "VJC", "VNM", "VPB", "VRE"
    ]

    transformer = DataTransformer(stock_codes, table_names)
    transformer.run(table_name="balance")
    transformer.run(table_name="inc_state")
    transformer.run(table_name="cash_flow")
# Out:
# 🔄 Đang xử lý: ACB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\ACB_csv\ACB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\ACB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\ACB_processed.xlsx
#
# 🔄 Đang xử lý: BCM - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BCM_csv\BCM_tbl-data-CDKT_7.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\BCM_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\BCM_processed.xlsx
#
# 🔄 Đang xử lý: BID - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BID_csv\BID_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\BID_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\BID_processed.xlsx
#
# 🔄 Đang xử lý: BVH - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\BVH_csv\BVH_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\BVH_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\BVH_processed.xlsx
#
# 🔄 Đang xử lý: CTG - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\CTG_csv\CTG_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\CTG_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\CTG_processed.xlsx
#
# 🔄 Đang xử lý: FPT - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\FPT_csv\FPT_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\FPT_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\FPT_processed.xlsx
#
# 🔄 Đang xử lý: GAS - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GAS_csv\GAS_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\GAS_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\GAS_processed.xlsx
#
# 🔄 Đang xử lý: GVR - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\GVR_csv\GVR_tbl-data-CDKT_7.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\GVR_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\GVR_processed.xlsx
#
# 🔄 Đang xử lý: HDB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HDB_csv\HDB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\HDB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\HDB_processed.xlsx
#
# 🔄 Đang xử lý: HPG - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\HPG_csv\HPG_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\HPG_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\HPG_processed.xlsx
#
# 🔄 Đang xử lý: LPB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\LPB_csv\LPB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\LPB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\LPB_processed.xlsx
#
# 🔄 Đang xử lý: MBB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MBB_csv\MBB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\MBB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\MBB_processed.xlsx
#
# 🔄 Đang xử lý: MSN - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MSN_csv\MSN_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\MSN_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\MSN_processed.xlsx
#
# 🔄 Đang xử lý: MWG - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\MWG_csv\MWG_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\MWG_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\MWG_processed.xlsx
#
# 🔄 Đang xử lý: PLX - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\PLX_csv\PLX_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\PLX_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\PLX_processed.xlsx
#
# 🔄 Đang xử lý: SAB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SAB_csv\SAB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\SAB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\SAB_processed.xlsx
#
# 🔄 Đang xử lý: SHB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SHB_csv\SHB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\SHB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\SHB_processed.xlsx
#
# 🔄 Đang xử lý: SSB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSB_csv\SSB_tbl-data-CDKT_7.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\SSB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\SSB_processed.xlsx
#
# 🔄 Đang xử lý: SSI - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\SSI_csv\SSI_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\SSI_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\SSI_processed.xlsx
#
# 🔄 Đang xử lý: STB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\STB_csv\STB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\STB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\STB_processed.xlsx
#
# 🔄 Đang xử lý: TCB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TCB_csv\TCB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\TCB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\TCB_processed.xlsx
#
# 🔄 Đang xử lý: TPB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\TPB_csv\TPB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\TPB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\TPB_processed.xlsx
#
# 🔄 Đang xử lý: VCB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VCB_csv\VCB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\VCB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\VCB_processed.xlsx
#
# 🔄 Đang xử lý: VHM - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VHM_csv\VHM_tbl-data-CDKT_8.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\VHM_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\VHM_processed.xlsx
#
# 🔄 Đang xử lý: VIC - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VIC_csv\VIC_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\VIC_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\VIC_processed.xlsx
#
# 🔄 Đang xử lý: VJC - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VJC_csv\VJC_tbl-data-CDKT_8.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\VJC_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\VJC_processed.xlsx
#
# 🔄 Đang xử lý: VNM - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_16.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VNM_csv\VNM_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\VNM_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\VNM_processed.xlsx
#
# 🔄 Đang xử lý: VPB - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VPB_csv\VPB_tbl-data-CDKT_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\VPB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\VPB_processed.xlsx
#
# 🔄 Đang xử lý: VRE - balance
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\balance\VRE_csv\VRE_tbl-data-CDKT_7.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\balance\VRE_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\balance\VRE_processed.xlsx
#
# 🔄 Đang xử lý: ACB - inc_state
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\ACB_csv\ACB_tbl-data-KQKD_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\inc_state\ACB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\inc_state\ACB_processed.xlsx
#
# 🔄 Đang xử lý: BCM - inc_state
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-KQKD_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-KQKD_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-KQKD_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-KQKD_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-KQKD_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-KQKD_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BCM_csv\BCM_tbl-data-KQKD_7.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\inc_state\BCM_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\inc_state\BCM_processed.xlsx
#
# 🔄 Đang xử lý: BID - inc_state
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BID_csv\BID_tbl-data-KQKD_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\inc_state\BID_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\inc_state\BID_processed.xlsx
#
# 🔄 Đang xử lý: BVH - inc_state
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\BVH_csv\BVH_tbl-data-KQKD_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\inc_state\BVH_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\inc_state\BVH_processed.xlsx
#
# 🔄 Đang xử lý: CTG - inc_state
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\CTG_csv\CTG_tbl-data-KQKD_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\inc_state\CTG_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\inc_state\CTG_processed.xlsx
#
# 🔄 Đang xử lý: FPT - inc_state
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\FPT_csv\FPT_tbl-data-KQKD_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\inc_state\FPT_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\inc_state\FPT_processed.xlsx
#
# 🔄 Đang xử lý: GAS - inc_state
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-CDKT_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GAS_csv\GAS_tbl-data-KQKD_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\inc_state\GAS_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\inc_state\GAS_processed.xlsx
#
# 🔄 Đang xử lý: GVR - inc_state
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-CDKT_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-CDKT_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-CDKT_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-CDKT_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-CDKT_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-CDKT_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-CDKT_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-KQKD_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-KQKD_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-KQKD_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-KQKD_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\inc_state\GVR_csv\GVR_tbl-data-KQKD_5.csv
# ...
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-direct_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\STB_csv\STB_tbl-data-LCTT-indirect_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\STB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\STB_processed.xlsx
#
# 🔄 Đang xử lý: TCB - cash_flow
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-direct_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TCB_csv\TCB_tbl-data-LCTT-indirect_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\TCB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\TCB_processed.xlsx
#
# 🔄 Đang xử lý: TPB - cash_flow
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-direct_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-direct_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-direct_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-direct_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-direct_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-direct_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-direct_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-direct_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-direct_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-indirect_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-indirect_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\TPB_csv\TPB_tbl-data-LCTT-indirect_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\TPB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\TPB_processed.xlsx
#
# 🔄 Đang xử lý: VCB - cash_flow
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-direct_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VCB_csv\VCB_tbl-data-LCTT-indirect_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\VCB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\VCB_processed.xlsx
#
# 🔄 Đang xử lý: VHM - cash_flow
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VHM_csv\VHM_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VHM_csv\VHM_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VHM_csv\VHM_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VHM_csv\VHM_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VHM_csv\VHM_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VHM_csv\VHM_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VHM_csv\VHM_tbl-data-LCTT-indirect_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VHM_csv\VHM_tbl-data-LCTT-indirect_8.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\VHM_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\VHM_processed.xlsx
#
# 🔄 Đang xử lý: VIC - cash_flow
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VIC_csv\VIC_tbl-data-LCTT-indirect_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\VIC_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\VIC_processed.xlsx
#
# 🔄 Đang xử lý: VJC - cash_flow
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VJC_csv\VJC_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VJC_csv\VJC_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VJC_csv\VJC_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VJC_csv\VJC_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VJC_csv\VJC_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VJC_csv\VJC_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VJC_csv\VJC_tbl-data-LCTT-indirect_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VJC_csv\VJC_tbl-data-LCTT-indirect_8.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\VJC_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\VJC_processed.xlsx
#
# 🔄 Đang xử lý: VNM - cash_flow
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_11.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_12.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_13.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_14.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_15.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_16.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VNM_csv\VNM_tbl-data-LCTT-indirect_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\VNM_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\VNM_processed.xlsx
#
# 🔄 Đang xử lý: VPB - cash_flow
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-direct_9.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_10.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_7.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_8.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VPB_csv\VPB_tbl-data-LCTT-indirect_9.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\VPB_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\VPB_processed.xlsx
#
# 🔄 Đang xử lý: VRE - cash_flow
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VRE_csv\VRE_tbl-data-LCTT-indirect_1.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VRE_csv\VRE_tbl-data-LCTT-indirect_2.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VRE_csv\VRE_tbl-data-LCTT-indirect_3.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VRE_csv\VRE_tbl-data-LCTT-indirect_4.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VRE_csv\VRE_tbl-data-LCTT-indirect_5.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VRE_csv\VRE_tbl-data-LCTT-indirect_6.csv
# 🔄 Đang xử lý: ..\..\parsed_data_raw\csv\cash_flow\VRE_csv\VRE_tbl-data-LCTT-indirect_7.csv
# ✅ File CSV đã được lưu tại: processed_data\csv\cash_flow\VRE_transformed.csv
# ✅ File Excel đã được lưu tại: processed_data\excel\cash_flow\VRE_processed.xlsx

# %%
# import csv
# import os
# import openpyxl
# from collections import defaultdict

# class DataTransformer:
#     def __init__(self, stock_codes, table_names, input_folder="parsed_data_raw", output_folder="processed_data"):
#         self.stock_codes = stock_codes
#         self.table_names = table_names
#         self.input_folder = input_folder
#         self.output_folder = output_folder

#     def process_financial_report(self, stock_code, table_name):
#         """Xử lý báo cáo tài chính và giữ nguyên thứ tự index"""
        
#         # 📁 Đường dẫn input và output
#         input_folder_path = os.path.join("..", "..", "parsed_data_raw", "csv", table_name, f"{stock_code}_csv")
#         output_folder_path = os.path.join(self.output_folder, "csv", table_name, f"{stock_code}_processed")
#         os.makedirs(output_folder_path, exist_ok=True)

#         data_dict = defaultdict(dict)  # Lưu dữ liệu dạng { (stock_code, time): {index: value} }
#         index_order = []  # Giữ nguyên thứ tự xuất hiện của index

#         # 📂 Đọc từng file CSV
#         for file_name in os.listdir(input_folder_path):
#             if file_name.endswith(".csv"):
#                 input_csv = os.path.join(input_folder_path, file_name)
#                 print(f"🔄 Đang xử lý: {input_csv}")

#                 with open(input_csv, "r", encoding="utf-8") as f:
#                     reader = csv.reader(f)
#                     headers = next(reader)  # Lấy tiêu đề (bỏ qua)

#                     quarters = headers[1:]  # Các cột quý (VD: "2023/Q1", "2023/Q2")

#                     for row in reader:
#                         indicator = row[0].strip()

#                         if indicator in ["Giai đoạn", "Hợp nhất", "Kiểm toán", "Công ty kiểm toán", "Ý kiến kiểm toán"]:
#                             continue  # Bỏ qua các chỉ số không cần thiết

#                         # 🔄 Duy trì thứ tự index
#                         if indicator not in index_order:
#                             index_order.append(indicator)

#                         for i, quarter in enumerate(quarters):
#                             quarter_formatted = quarter.replace("/", "")  # Chuẩn hóa định dạng thời gian
#                             value = row[i + 1].replace(",", "").strip()

#                             if value not in ["", "nan", "None"]:  # Bỏ qua giá trị rỗng
#                                 data_dict[(stock_code, quarter_formatted)][indicator] = float(value)

#         # 📁 Ghi dữ liệu ra file CSV
#         output_csv = os.path.join(output_folder_path, f"{stock_code}_transformed.csv")
#         data_list = []

#         with open(output_csv, "w", encoding="utf-8", newline="") as f:
#             writer = csv.writer(f)

#             # 📝 Ghi header: ["stock_code", "time", chỉ số tài chính...]
#             writer.writerow(["stock_code", "time"] + index_order)

#             # 📝 Ghi dữ liệu theo thứ tự
#             for (stock_code, time), values in sorted(data_dict.items()):
#                 row = [stock_code, time] + [values.get(index, "") for index in index_order]
#                 writer.writerow(row)
#                 data_list.append(row)

#         print(f"✅ File CSV đã được lưu tại: {output_csv}")

#         # 📁 Ghi dữ liệu ra file Excel
#         output_excel = os.path.join(output_folder_path, f"{stock_code}_processed_excel.xlsx")
#         self.save_to_excel(output_excel, ["stock_code", "time"] + index_order, data_list)

#     def save_to_excel(self, file_path, headers, data):
#         """Lưu dữ liệu vào file Excel"""
#         workbook = openpyxl.Workbook()
#         sheet = workbook.active
#         sheet.append(headers)  # Ghi tiêu đề

#         for row in data:
#             sheet.append(row)  # Ghi dữ liệu

#         workbook.save(file_path)
#         print(f"✅ File Excel đã được lưu tại: {file_path}")

#     def run(self, table_name):
#         for stock_code in self.stock_codes:
#             print(f"\n🔄 Đang xử lý: {stock_code} - {table_name}")
#             self.process_financial_report(stock_code, table_name)

# if __name__ == "__main__":
#     stock_codes = [
#         "ACB", "BCM", "BID", "BVH", "CTG", "FPT", "GAS", "GVR", "HDB", "HPG",
#         "LPB", "MBB", "MSN", "MWG", "PLX", "SAB", "SHB", "SSB",
#         "SSI", "STB",
#         "TCB", "TPB", "VCB", "VHM", "VIC", "VJC", "VNM", "VPB", "VRE"
#     ]
#     table_names = {"balance"}

#     transformer = DataTransformer(stock_codes, table_names)
#     transformer.run(table_name="balance")

# %%
import os
import pandas as pd

groups_folder_path = os.path.join("processed_data/csv/balance")
group1 = []
group2 = []

# Lặp qua tất cả các file trong thư mục
for filename in os.listdir(groups_folder_path):
    if filename.endswith("_transformed.csv"):  # Chỉ xử lý các file có cấu trúc mong muốn
        file_path = os.path.join(groups_folder_path, filename)

        try:
            # Đọc chỉ tên cột của file CSV
            df = pd.read_csv(file_path, nrows=0)  # Đọc dòng header (tên cột)
            column_names = df.columns.astype(str).to_list()  # Chuyển danh sách cột thành string list

            stockcode = filename.replace("_transformed.csv", "")
            if any("Tiền và các khoản tương đương tiền" in col for col in column_names):
                group1.append(stockcode)
            else:
                group2.append(stockcode)

        except Exception as e:
            print(f"Lỗi khi đọc file {filename}: {e}")

print("Group 1:", group1)
print("Group 2:", group2)
# Out:
# Group 1: ['BCM', 'BVH', 'FPT', 'GAS', 'GVR', 'HPG', 'MSN', 'MWG', 'PLX', 'SAB', 'SSI', 'VHM', 'VIC', 'VJC', 'VNM', 'VRE']
# Group 2: ['ACB', 'BID', 'CTG', 'HDB', 'LPB', 'MBB', 'SHB', 'SSB', 'STB', 'TCB', 'TPB', 'VCB', 'VPB']

# %%
import os
import pandas as pd

groups_folder_path = os.path.join("processed_data/csv/inc_state")
group1 = []
group2 = []

# Lặp qua tất cả các file trong thư mục
for filename in os.listdir(groups_folder_path):
    if filename.endswith("_transformed.csv"):  # Chỉ xử lý các file có cấu trúc mong muốn
        file_path = os.path.join(groups_folder_path, filename)

        try:
            # Đọc chỉ tên cột của file CSV
            df = pd.read_csv(file_path, nrows=0)  # Đọc dòng header (tên cột)
            column_names = df.columns.astype(str).to_list()  # Chuyển danh sách cột thành string list

            stockcode = filename.replace("_transformed.csv", "")
            if any("Doanh thu bán hàng và cung cấp dịch vụ" in col for col in column_names):
                group1.append(stockcode)
            else:
                group2.append(stockcode)

        except Exception as e:
            print(f"Lỗi khi đọc file {filename}: {e}")

print("Group 1:", group1)
print("Group 2:", group2)
# Out:
# Group 1: ['BCM', 'FPT', 'GAS', 'GVR', 'HPG', 'MSN', 'MWG', 'PLX', 'SAB', 'VHM', 'VIC', 'VJC', 'VNM', 'VRE']
# Group 2: ['ACB', 'BID', 'BVH', 'CTG', 'HDB', 'LPB', 'MBB', 'SHB', 'SSB', 'SSI', 'STB', 'TCB', 'TPB', 'VCB', 'VPB']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
